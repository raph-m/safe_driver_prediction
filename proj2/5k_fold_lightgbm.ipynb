# %%
import lightgbm as lgb
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold

from preprocessing import preproc
from tools import log_loss_lgbm

from datetime import datetime
import time

path_to_data = "/home/raph/Downloads/"

print("loading data")
training = pd.read_csv(path_to_data+"training.csv")
testing = pd.read_csv(path_to_data+"testing.csv")
# Out:
# loading data

# %%
print("changing dates to time stamps")
training["membership_expire_date"] = training.membership_expire_date.apply(lambda x: datetime.strptime(str(x), "%Y-%m-%d").date() if pd.notnull(x) else x)
training["membership_expire_date"] = training.membership_expire_date.apply(lambda x: time.mktime(x.timetuple()) if pd.notnull(x) else 0.0)

training["transaction_date"] = training.transaction_date.apply(lambda x: datetime.strptime(str(x), "%Y-%m-%d").date() if pd.notnull(x) else x)
training["transaction_date"] = training.transaction_date.apply(lambda x: time.mktime(x.timetuple()) if pd.notnull(x) else 0.0)

training["registration_init_time"] = training.registration_init_time.apply(lambda x: datetime.strptime(str(x), "%Y-%m-%d").date() if pd.notnull(x) else x)
training["registration_init_time"] = training.registration_init_time.apply(lambda x: time.mktime(x.timetuple()) if pd.notnull(x) else 0.0)

testing["membership_expire_date"] = testing.membership_expire_date.apply(lambda x: datetime.strptime(str(x), "%Y-%m-%d").date() if pd.notnull(x) else x)
testing["membership_expire_date"] = testing.membership_expire_date.apply(lambda x: time.mktime(x.timetuple()) if pd.notnull(x) else 0.0)

testing["transaction_date"] = testing.transaction_date.apply(lambda x: datetime.strptime(str(x), "%Y-%m-%d").date() if pd.notnull(x) else x)
testing["transaction_date"] = testing.transaction_date.apply(lambda x: time.mktime(x.timetuple()) if pd.notnull(x) else 0.0)

testing["registration_init_time"] = testing.registration_init_time.apply(lambda x: datetime.strptime(str(x), "%Y-%m-%d").date() if pd.notnull(x) else x)
testing["registration_init_time"] = testing.registration_init_time.apply(lambda x: time.mktime(x.timetuple()) if pd.notnull(x) else 0.0)
# Out:
# changing dates to time stamps

# %%
testing = testing.drop(["registration_init_time"], axis=1)
testing = testing.drop(["transaction_date"], axis=1)
testing = testing.drop(["membership_expire_date"], axis=1)
training = training.drop(["registration_init_time"], axis=1)
training = training.drop(["transaction_date"], axis=1)
training = training.drop(["membership_expire_date"], axis=1)

# %%
training.head()
# Out:
#                                            msno  actual_amount_paid  bd  city  \
# 0  +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=                99.0  -1     1
# 1  +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=               149.0  26    15
# 2  +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=               149.0  -1     1
# 3  ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=               149.0  21    18
# 4  ++/UDNo9DLrxT8QVGiDi1OnWfczAdEwThaVyD0fXO50=               149.0  32    22
#
#    gender  is_auto_renew  is_cancel  is_churn  payment_method_id  \
# 0      -1            1.0        0.0         0               41.0
# 1       0            1.0        0.0         0               39.0
# 2      -1            1.0        0.0         0               41.0
# 3       0            1.0        0.0         0               41.0
# 4       0            1.0        0.0         0               39.0
#
#    payment_plan_days  plan_list_price  registered_via  \
# 0               30.0             99.0               7
# 1               30.0            149.0               9
# 2               30.0            149.0               7
# 3               30.0            149.0               7
# 4               30.0            149.0               9
#
#    total_number_of_transactions  usual_price_per_day  price_per_day  \
# 0                             3             2.990033       3.298900
# 1                            19           788.374540       4.965012
# 2                            26           577.585544       4.965012
# 3                            12             4.746045       4.965012
# 4                            19           788.374540       4.965012
#
#    price_per_day_diff
# 0            0.308867
# 1         -783.409528
# 2         -572.620532
# 3            0.218967
# 4         -783.409528

# %%
print("preprocessing")
X_train, y_train = preproc(training, mode='train', oneHot=False)
X_test, y_test = preproc(testing, mode="test", oneHot=False)

# parameters
params = {
    'task': 'train',
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': {'binary_logloss'},
    'num_leaves': 31,
    'learning_rate': 0.1,
    'feature_fraction': 0.8,
    'bagging_fraction': 0.8,
    'bagging_freq': 5,
    'verbose': 0
}

i = 0
K = 5
kf = KFold(n_splits=K, random_state=42, shuffle=True)

# training with KFold Cross Validation
weights = np.zeros(len(y_train))
weights[y_train == 0] = 1
weights[y_train == 1] = 1
# Out:
# preprocessing

# %%
results = []
from tools import log_loss
print('Start training...')
for train_index, test_index in kf.split(X_train):
    lgb_train = lgb.Dataset(X_train[train_index], y_train[train_index], weight=weights[train_index])
    lgb_eval = lgb.Dataset(X_train[test_index], y_train[test_index], reference=lgb_train)
    gbm = lgb.train(params,
        train_set=lgb_train,
        num_boost_round=200,
        valid_sets=lgb_eval,
        early_stopping_rounds=30,
        verbose_eval=5,
        feval=log_loss_lgbm)
    res = gbm.predict(X_test)
    i += 1
    results.append(res)
    
    print("my log loss train")
    print(log_loss(y_train[train_index], gbm.predict(X_train[train_index])))
    print("my log loss test")
    print(log_loss(y_train[test_index], gbm.predict(X_train[test_index])))
# Out:
# Start training...
# Training until validation scores don't improve for 30 rounds.
# [5]	valid_0's binary_logloss: 0.422479	valid_0's log loss: 0.422479
# [10]	valid_0's binary_logloss: 0.300725	valid_0's log loss: 0.300725
# [15]	valid_0's binary_logloss: 0.240247	valid_0's log loss: 0.240247
# [20]	valid_0's binary_logloss: 0.208838	valid_0's log loss: 0.208838
# [25]	valid_0's binary_logloss: 0.191959	valid_0's log loss: 0.191959
# [30]	valid_0's binary_logloss: 0.183268	valid_0's log loss: 0.183268
# [35]	valid_0's binary_logloss: 0.178246	valid_0's log loss: 0.178246
# [40]	valid_0's binary_logloss: 0.175447	valid_0's log loss: 0.175447
# [45]	valid_0's binary_logloss: 0.173783	valid_0's log loss: 0.173783
# [50]	valid_0's binary_logloss: 0.172726	valid_0's log loss: 0.172726
# [55]	valid_0's binary_logloss: 0.172049	valid_0's log loss: 0.172049
# [60]	valid_0's binary_logloss: 0.171591	valid_0's log loss: 0.171591
# [65]	valid_0's binary_logloss: 0.171245	valid_0's log loss: 0.171245
# [70]	valid_0's binary_logloss: 0.17083	valid_0's log loss: 0.17083
# [75]	valid_0's binary_logloss: 0.170617	valid_0's log loss: 0.170617
# [80]	valid_0's binary_logloss: 0.170474	valid_0's log loss: 0.170474
# [85]	valid_0's binary_logloss: 0.170366	valid_0's log loss: 0.170366
# [90]	valid_0's binary_logloss: 0.170208	valid_0's log loss: 0.170208
# [95]	valid_0's binary_logloss: 0.170074	valid_0's log loss: 0.170074
# [100]	valid_0's binary_logloss: 0.169981	valid_0's log loss: 0.169981
# [105]	valid_0's binary_logloss: 0.169948	valid_0's log loss: 0.169948
# [110]	valid_0's binary_logloss: 0.16987	valid_0's log loss: 0.16987
# [115]	valid_0's binary_logloss: 0.169812	valid_0's log loss: 0.169812
# [120]	valid_0's binary_logloss: 0.169773	valid_0's log loss: 0.169773
# [125]	valid_0's binary_logloss: 0.169727	valid_0's log loss: 0.169727
# [130]	valid_0's binary_logloss: 0.169716	valid_0's log loss: 0.169716
# [135]	valid_0's binary_logloss: 0.169627	valid_0's log loss: 0.169627
# [140]	valid_0's binary_logloss: 0.169552	valid_0's log loss: 0.169552
# [145]	valid_0's binary_logloss: 0.169477	valid_0's log loss: 0.169477
# [150]	valid_0's binary_logloss: 0.169464	valid_0's log loss: 0.169464
# [155]	valid_0's binary_logloss: 0.169457	valid_0's log loss: 0.169457
# [160]	valid_0's binary_logloss: 0.169462	valid_0's log loss: 0.169462
# [165]	valid_0's binary_logloss: 0.169411	valid_0's log loss: 0.169411
# [170]	valid_0's binary_logloss: 0.16938	valid_0's log loss: 0.16938
# [175]	valid_0's binary_logloss: 0.169379	valid_0's log loss: 0.169379
# [180]	valid_0's binary_logloss: 0.16934	valid_0's log loss: 0.16934
# [185]	valid_0's binary_logloss: 0.16931	valid_0's log loss: 0.16931
# [190]	valid_0's binary_logloss: 0.169285	valid_0's log loss: 0.169285
# [195]	valid_0's binary_logloss: 0.169219	valid_0's log loss: 0.169219
# [200]	valid_0's binary_logloss: 0.16921	valid_0's log loss: 0.16921
# my log loss train
# 0.16743050254
# my log loss test
# 0.169210432839
# Training until validation scores don't improve for 30 rounds.
# [5]	valid_0's binary_logloss: 0.422635	valid_0's log loss: 0.422635
# [10]	valid_0's binary_logloss: 0.301116	valid_0's log loss: 0.301116
# [15]	valid_0's binary_logloss: 0.240698	valid_0's log loss: 0.240698
# [20]	valid_0's binary_logloss: 0.209391	valid_0's log loss: 0.209391
# [25]	valid_0's binary_logloss: 0.192846	valid_0's log loss: 0.192846
# [30]	valid_0's binary_logloss: 0.184092	valid_0's log loss: 0.184092
# [35]	valid_0's binary_logloss: 0.179205	valid_0's log loss: 0.179205
# [40]	valid_0's binary_logloss: 0.176509	valid_0's log loss: 0.176509
# [45]	valid_0's binary_logloss: 0.174782	valid_0's log loss: 0.174782
# [50]	valid_0's binary_logloss: 0.17376	valid_0's log loss: 0.17376
# [55]	valid_0's binary_logloss: 0.173177	valid_0's log loss: 0.173177
# [60]	valid_0's binary_logloss: 0.172736	valid_0's log loss: 0.172736
# [65]	valid_0's binary_logloss: 0.172364	valid_0's log loss: 0.172364
# [70]	valid_0's binary_logloss: 0.172129	valid_0's log loss: 0.172129
# [75]	valid_0's binary_logloss: 0.171926	valid_0's log loss: 0.171926
# [80]	valid_0's binary_logloss: 0.171736	valid_0's log loss: 0.171736
# [85]	valid_0's binary_logloss: 0.171602	valid_0's log loss: 0.171602
# [90]	valid_0's binary_logloss: 0.171461	valid_0's log loss: 0.171461
# [95]	valid_0's binary_logloss: 0.171384	valid_0's log loss: 0.171384
# [100]	valid_0's binary_logloss: 0.171329	valid_0's log loss: 0.171329
# [105]	valid_0's binary_logloss: 0.171243	valid_0's log loss: 0.171243
# [110]	valid_0's binary_logloss: 0.171227	valid_0's log loss: 0.171227
# [115]	valid_0's binary_logloss: 0.171226	valid_0's log loss: 0.171226
# [120]	valid_0's binary_logloss: 0.171134	valid_0's log loss: 0.171134
# [125]	valid_0's binary_logloss: 0.171008	valid_0's log loss: 0.171008
# [130]	valid_0's binary_logloss: 0.170927	valid_0's log loss: 0.170927
# [135]	valid_0's binary_logloss: 0.170841	valid_0's log loss: 0.170841
# [140]	valid_0's binary_logloss: 0.17083	valid_0's log loss: 0.17083
# [145]	valid_0's binary_logloss: 0.170732	valid_0's log loss: 0.170732
# [150]	valid_0's binary_logloss: 0.170707	valid_0's log loss: 0.170707
# [155]	valid_0's binary_logloss: 0.170675	valid_0's log loss: 0.170675
# [160]	valid_0's binary_logloss: 0.170632	valid_0's log loss: 0.170632
# [165]	valid_0's binary_logloss: 0.170614	valid_0's log loss: 0.170614
# [170]	valid_0's binary_logloss: 0.17061	valid_0's log loss: 0.17061
# [175]	valid_0's binary_logloss: 0.170596	valid_0's log loss: 0.170596
# [180]	valid_0's binary_logloss: 0.170566	valid_0's log loss: 0.170566
# [185]	valid_0's binary_logloss: 0.170585	valid_0's log loss: 0.170585
# [190]	valid_0's binary_logloss: 0.170527	valid_0's log loss: 0.170527
# [195]	valid_0's binary_logloss: 0.170522	valid_0's log loss: 0.170522
# [200]	valid_0's binary_logloss: 0.17053	valid_0's log loss: 0.17053
# my log loss train
# 0.167243555681
# my log loss test
# 0.17053012784
# Training until validation scores don't improve for 30 rounds.
# [5]	valid_0's binary_logloss: 0.422654	valid_0's log loss: 0.422654
# [10]	valid_0's binary_logloss: 0.301123	valid_0's log loss: 0.301123
# [15]	valid_0's binary_logloss: 0.240918	valid_0's log loss: 0.240918
# [20]	valid_0's binary_logloss: 0.209799	valid_0's log loss: 0.209799
# [25]	valid_0's binary_logloss: 0.193559	valid_0's log loss: 0.193559
# [30]	valid_0's binary_logloss: 0.184702	valid_0's log loss: 0.184702
# [35]	valid_0's binary_logloss: 0.179797	valid_0's log loss: 0.179797
# [40]	valid_0's binary_logloss: 0.177176	valid_0's log loss: 0.177176
# [45]	valid_0's binary_logloss: 0.175508	valid_0's log loss: 0.175508
# [50]	valid_0's binary_logloss: 0.174563	valid_0's log loss: 0.174563
# [55]	valid_0's binary_logloss: 0.173873	valid_0's log loss: 0.173873
# [60]	valid_0's binary_logloss: 0.173432	valid_0's log loss: 0.173432
# [65]	valid_0's binary_logloss: 0.173062	valid_0's log loss: 0.173062
# [70]	valid_0's binary_logloss: 0.172835	valid_0's log loss: 0.172835
# [75]	valid_0's binary_logloss: 0.172664	valid_0's log loss: 0.172664
# [80]	valid_0's binary_logloss: 0.17244	valid_0's log loss: 0.17244
# [85]	valid_0's binary_logloss: 0.172285	valid_0's log loss: 0.172285
# [90]	valid_0's binary_logloss: 0.172094	valid_0's log loss: 0.172094
# [95]	valid_0's binary_logloss: 0.172047	valid_0's log loss: 0.172047
# [100]	valid_0's binary_logloss: 0.171955	valid_0's log loss: 0.171955
# [105]	valid_0's binary_logloss: 0.171807	valid_0's log loss: 0.171807
# [110]	valid_0's binary_logloss: 0.171727	valid_0's log loss: 0.171727
# [115]	valid_0's binary_logloss: 0.171642	valid_0's log loss: 0.171642
# [120]	valid_0's binary_logloss: 0.171589	valid_0's log loss: 0.171589
# [125]	valid_0's binary_logloss: 0.171548	valid_0's log loss: 0.171548
# [130]	valid_0's binary_logloss: 0.171516	valid_0's log loss: 0.171516
# [135]	valid_0's binary_logloss: 0.171446	valid_0's log loss: 0.171446
# [140]	valid_0's binary_logloss: 0.17142	valid_0's log loss: 0.17142
# [145]	valid_0's binary_logloss: 0.171334	valid_0's log loss: 0.171334
# [150]	valid_0's binary_logloss: 0.171194	valid_0's log loss: 0.171194
# [155]	valid_0's binary_logloss: 0.171148	valid_0's log loss: 0.171148
# [160]	valid_0's binary_logloss: 0.17109	valid_0's log loss: 0.17109
# [165]	valid_0's binary_logloss: 0.171058	valid_0's log loss: 0.171058
# [170]	valid_0's binary_logloss: 0.171027	valid_0's log loss: 0.171027
# [175]	valid_0's binary_logloss: 0.170999	valid_0's log loss: 0.170999
# [180]	valid_0's binary_logloss: 0.170981	valid_0's log loss: 0.170981
# [185]	valid_0's binary_logloss: 0.170952	valid_0's log loss: 0.170952
# [190]	valid_0's binary_logloss: 0.170932	valid_0's log loss: 0.170932
# [195]	valid_0's binary_logloss: 0.170924	valid_0's log loss: 0.170924
# [200]	valid_0's binary_logloss: 0.170921	valid_0's log loss: 0.170921
# my log loss train
# 0.166658897017
# my log loss test
# 0.170921095865
# Training until validation scores don't improve for 30 rounds.
# [5]	valid_0's binary_logloss: 0.422005	valid_0's log loss: 0.422005
# [10]	valid_0's binary_logloss: 0.300064	valid_0's log loss: 0.300064
# [15]	valid_0's binary_logloss: 0.239342	valid_0's log loss: 0.239342
# [20]	valid_0's binary_logloss: 0.207811	valid_0's log loss: 0.207811
# [25]	valid_0's binary_logloss: 0.190767	valid_0's log loss: 0.190767
# [30]	valid_0's binary_logloss: 0.181917	valid_0's log loss: 0.181917
# [35]	valid_0's binary_logloss: 0.176796	valid_0's log loss: 0.176796
# [40]	valid_0's binary_logloss: 0.173922	valid_0's log loss: 0.173922
# [45]	valid_0's binary_logloss: 0.172246	valid_0's log loss: 0.172246
# [50]	valid_0's binary_logloss: 0.171091	valid_0's log loss: 0.171091
# [55]	valid_0's binary_logloss: 0.170301	valid_0's log loss: 0.170301
# [60]	valid_0's binary_logloss: 0.169841	valid_0's log loss: 0.169841
# [65]	valid_0's binary_logloss: 0.16941	valid_0's log loss: 0.16941
# [70]	valid_0's binary_logloss: 0.16911	valid_0's log loss: 0.16911
# [75]	valid_0's binary_logloss: 0.168938	valid_0's log loss: 0.168938
# [80]	valid_0's binary_logloss: 0.16868	valid_0's log loss: 0.16868
# [85]	valid_0's binary_logloss: 0.168533	valid_0's log loss: 0.168533
# [90]	valid_0's binary_logloss: 0.168382	valid_0's log loss: 0.168382
# [95]	valid_0's binary_logloss: 0.168273	valid_0's log loss: 0.168273
# [100]	valid_0's binary_logloss: 0.168165	valid_0's log loss: 0.168165
# [105]	valid_0's binary_logloss: 0.168116	valid_0's log loss: 0.168116
# [110]	valid_0's binary_logloss: 0.168039	valid_0's log loss: 0.168039
# [115]	valid_0's binary_logloss: 0.167956	valid_0's log loss: 0.167956
# [120]	valid_0's binary_logloss: 0.167863	valid_0's log loss: 0.167863
# [125]	valid_0's binary_logloss: 0.167778	valid_0's log loss: 0.167778
# [130]	valid_0's binary_logloss: 0.167715	valid_0's log loss: 0.167715
# [135]	valid_0's binary_logloss: 0.167658	valid_0's log loss: 0.167658
# [140]	valid_0's binary_logloss: 0.167606	valid_0's log loss: 0.167606
# [145]	valid_0's binary_logloss: 0.167606	valid_0's log loss: 0.167606
# [150]	valid_0's binary_logloss: 0.167556	valid_0's log loss: 0.167556
# [155]	valid_0's binary_logloss: 0.167523	valid_0's log loss: 0.167523
# [160]	valid_0's binary_logloss: 0.167486	valid_0's log loss: 0.167486
# [165]	valid_0's binary_logloss: 0.167449	valid_0's log loss: 0.167449
# [170]	valid_0's binary_logloss: 0.167371	valid_0's log loss: 0.167371
# [175]	valid_0's binary_logloss: 0.167351	valid_0's log loss: 0.167351
# [180]	valid_0's binary_logloss: 0.167301	valid_0's log loss: 0.167301
# [185]	valid_0's binary_logloss: 0.167294	valid_0's log loss: 0.167294
# [190]	valid_0's binary_logloss: 0.167262	valid_0's log loss: 0.167262
# [195]	valid_0's binary_logloss: 0.167213	valid_0's log loss: 0.167213
# [200]	valid_0's binary_logloss: 0.167199	valid_0's log loss: 0.167199
# my log loss train
# 0.167918106437
# my log loss test
# 0.167199465183
# Training until validation scores don't improve for 30 rounds.
# [5]	valid_0's binary_logloss: 0.42286	valid_0's log loss: 0.42286
# [10]	valid_0's binary_logloss: 0.301479	valid_0's log loss: 0.301479
# [15]	valid_0's binary_logloss: 0.241438	valid_0's log loss: 0.241438
# [20]	valid_0's binary_logloss: 0.210204	valid_0's log loss: 0.210204
# [25]	valid_0's binary_logloss: 0.193538	valid_0's log loss: 0.193538
# [30]	valid_0's binary_logloss: 0.1851	valid_0's log loss: 0.1851
# [35]	valid_0's binary_logloss: 0.180178	valid_0's log loss: 0.180178
# [40]	valid_0's binary_logloss: 0.177541	valid_0's log loss: 0.177541
# [45]	valid_0's binary_logloss: 0.175911	valid_0's log loss: 0.175911
# [50]	valid_0's binary_logloss: 0.17501	valid_0's log loss: 0.17501
# [55]	valid_0's binary_logloss: 0.17446	valid_0's log loss: 0.17446
# [60]	valid_0's binary_logloss: 0.173973	valid_0's log loss: 0.173973
# [65]	valid_0's binary_logloss: 0.173677	valid_0's log loss: 0.173677
# [70]	valid_0's binary_logloss: 0.173459	valid_0's log loss: 0.173459
# [75]	valid_0's binary_logloss: 0.173244	valid_0's log loss: 0.173244
# [80]	valid_0's binary_logloss: 0.173053	valid_0's log loss: 0.173053
# [85]	valid_0's binary_logloss: 0.172894	valid_0's log loss: 0.172894
# [90]	valid_0's binary_logloss: 0.172778	valid_0's log loss: 0.172778
# [95]	valid_0's binary_logloss: 0.172639	valid_0's log loss: 0.172639
# [100]	valid_0's binary_logloss: 0.172557	valid_0's log loss: 0.172557
# [105]	valid_0's binary_logloss: 0.17247	valid_0's log loss: 0.17247
# [110]	valid_0's binary_logloss: 0.1724	valid_0's log loss: 0.1724
# [115]	valid_0's binary_logloss: 0.172357	valid_0's log loss: 0.172357
# [120]	valid_0's binary_logloss: 0.172301	valid_0's log loss: 0.172301
# [125]	valid_0's binary_logloss: 0.172201	valid_0's log loss: 0.172201
# [130]	valid_0's binary_logloss: 0.172154	valid_0's log loss: 0.172154
# [135]	valid_0's binary_logloss: 0.172054	valid_0's log loss: 0.172054
# [140]	valid_0's binary_logloss: 0.172011	valid_0's log loss: 0.172011
# [145]	valid_0's binary_logloss: 0.171959	valid_0's log loss: 0.171959
# [150]	valid_0's binary_logloss: 0.171907	valid_0's log loss: 0.171907
# [155]	valid_0's binary_logloss: 0.171871	valid_0's log loss: 0.171871
# [160]	valid_0's binary_logloss: 0.17182	valid_0's log loss: 0.17182
# [165]	valid_0's binary_logloss: 0.171795	valid_0's log loss: 0.171795
# [170]	valid_0's binary_logloss: 0.17176	valid_0's log loss: 0.17176
# [175]	valid_0's binary_logloss: 0.171731	valid_0's log loss: 0.171731
# [180]	valid_0's binary_logloss: 0.171718	valid_0's log loss: 0.171718
# [185]	valid_0's binary_logloss: 0.171682	valid_0's log loss: 0.171682
# [190]	valid_0's binary_logloss: 0.171659	valid_0's log loss: 0.171659
# [195]	valid_0's binary_logloss: 0.171653	valid_0's log loss: 0.171653
# [200]	valid_0's binary_logloss: 0.171653	valid_0's log loss: 0.171653
# my log loss train
# 0.166835320053
# my log loss test
# 0.17165250105

# %%
submission = pd.DataFrame((results[0] + results[1] + results[2] + results[3] + results[4]) / 5)

# %%
submission.columns = ["is_churn"]

# %%
submission.describe()
# Out:
#             is_churn
# count  907471.000000
# mean        0.077824
# std         0.172544
# min         0.001102
# 25%         0.011251
# 50%         0.027100
# 75%         0.047170
# max         0.998154

# %%
submission["msno"] = testing["msno"]

# %%
submission.describe()
# Out:
#             is_churn
# count  907471.000000
# mean        0.077824
# std         0.172544
# min         0.001102
# 25%         0.011251
# 50%         0.027100
# 75%         0.047170
# max         0.998154

# %%
submission.head()
# Out:
#    is_churn                                          msno
# 0  0.003117  +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=
# 1  0.044958  +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=
# 2  0.034091  ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=
# 3  0.028496  ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=
# 4  0.204801  ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=

# %%
submission.to_csv('5Kfold_lgbm_drop_dates.csv', header=True, index=False)
print("created submission file")
# Out:
# created submission file

# %%
submission.describe()
